# %%
from sympy import simplify, cos, sin, symbols

# %%
X1, X2= symbols('X1 X2')
a = "(((4.294824698455102 * (X1  / (-4.532855240156618 / 0.02722632543021053))) * -0.17702714792331875) * (((4.286692986806084 * -2.295286580145861) + (0.7165152312258236 / (-1.3124560181182643 * (X1  / (-3.0521192366115235 / 0.02722632543021053))))) + ((((((((X1  / (-3.268266518937233 / 0.02722632543021053)) / -2.4828720491828316) * cos ((((4.294824698455102 * (X1  / (-3.9797675297314217 / 0.02722632543021053))) * -0.17702714792331875) - (((4.286692986806084 * -2.295286580145861) * (-0.8030967835373284 / 1.502803522589609)) + (-4.668758184299179 * sin (((-4.706050122654122 / ((((((0.9248455404856148 * cos (-0.8030967835373284)) * cos (-0.6772803359089856)) * cos ((1.725525250580903 / (4.294824698455102 * (X1  / (-4.532855240156618 / 0.02722632543021053)))))) / ((((0.7319020184995519 * sin (((-0.8030967835373284 / (-2.295286580145861 * -3.772389423815934)) * -2.3819662274423195))) + ((((((((X1  / (1.5619127903168764 / 0.02722632543021053)) / 2.5506236457358744) * cos ((-0.7586655817445873 * -2.9714227023910187))) + (0.7165152312258236 / ((X1  / -0.6772803359089856) * (X1  / (-0.17702714792331875 / 0.02722632543021053))))) / ((-2.014873404642997 - (0.9631156904079266 + (0.11626629221326645 * cos (-0.7610783078437011)))) + -0.6306779967229748)) - (((-3.268266518937233 + (3.9101278267447785 * sin (((-0.018447651526355635 / ((4.069440707133822 * cos ((((-3.506072867901373 * cos (3.0832869445877904)) * cos ((-0.9018396566669331 - (3.7225984886699433 - (((-1.3124560181182643 * (-1.8242034061176549 / ((3.144407971047613 * (-2.942954733179135 * 0.02722632543021053)) + (0.11626629221326645 - -0.7610783078437011)))) + (-2.295286580145861 / -1.416830288019547)) * (-2.2631716010801495 - 3.144407971047613)))))) + 0.7488565634620672))) + (-2.942954733179135 - (-2.083640215424969 * -4.532855240156618)))) + -2.942954733179135)))) / ((-2.014873404642997 - (-3.268266518937233 + (0.11626629221326645 * cos (-0.7610783078437011)))) + -0.6306779967229748)) - -4.706050122654122)) * cos ((((((0.11626629221326645 * cos (1.725525250580903)) - 3.8680221000152066) * cos ((((-4.11090649331188 * ((((((X1  - -0.6772803359089856) / -3.506072867901373) * cos ((3.9101278267447785 * -2.9714227023910187))) + -0.8030967835373284) * sin ((-4.11090649331188 * (-2.942954733179135 * (X1  / (-4.706050122654122 - 0.02722632543021053)))))) / (1.893549597835264 * sin (4.484771322004498)))) * sin (-3.772389423815934)) - -2.295286580145861))) * sin (((3.9101278267447785 * cos (4.484771322004498)) * cos (-4.706050122654122)))) * cos (((0.02722632543021053 + -0.6306779967229748) / 1.502803522589609))))) * cos (3.7225984886699433))) + -0.8030967835373284) * ((1.9658106059406837 * cos (((-0.6772803359089856 * (((-0.561048590151735 / 3.0832869445877904) * cos (((4.411341424668665 - 3.066872699769739) / 0.11626629221326645))) * 4.314395547737915)) * sin (-3.84539525743452)))) * sin ((1.465564941297096 * (3.8680221000152066 - ((((-3.506072867901373 * cos (0.11626629221326645)) * cos ((-3.84539525743452 - -3.268266518937233))) + 0.7488565634620672) * -1.416830288019547))))))) + ((-0.8030967835373284 / 1.502803522589609) - -2.8658768983251326)) + -1.9092825303046657)) + (-3.8816107891778118 + ((((-2.083640215424969 - 3.144407971047613) + 4.484771322004498) * ((((-0.561048590151735 * (X1  / (-3.6074558213210306 / 0.02722632543021053))) - -0.17702714792331875) * cos (1.725525250580903)) - ((((4.294824698455102 * (X1  / (-3.7356845247291037 / 0.02722632543021053))) * -0.17702714792331875) - (((4.286692986806084 * -2.295286580145861) + (-0.8030967835373284 / 1.502803522589609)) + 3.209347271590424)) * 0.7488565634620672))) + -2.036751075519234))))))))) * cos (-0.018447651526355635)) + (0.7319020184995519 - -2.8658768983251326)) * cos (((0.9248455404856148 * cos (0.7165152312258236)) / -2.7561400638530253))) / 3.9924282772107595) * sin (((0.7165152312258236 * sin (((((0.11626629221326645 - (-0.018447651526355635 * X1 )) * ((-1.5275901787742785 / -2.014873404642997) * 1.725525250580903)) * ((3.7225984886699433 * 2.2391214802060215) - -0.8030967835373284)) + ((-3.506072867901373 * cos (((-0.018447651526355635 * -2.036751075519234) - (3.9101278267447785 * -2.9714227023910187)))) - (-3.0567970546604717 * -4.532855240156618))))) * sin (-2.942954733179135))))))"
# a = "(((((1.0776951740449183 * -3.469164421572443) + ((X1  * 4.956970544260436) - -1.7777678383464068)) * X1 ) * X1 ) + ((((-4.153525890131531 - ((((4.0756214844543965 * cos (3.587233863676964)) + (1.457868710797797 * ((2.3744725008158323 * ((-0.45727096342888807 * (X1  / -3.673618613214983)) + -1.525181396731412)) / ((-4.188743390754595 / (-4.176047227006968 / (0.7895433938363041 + (4.009793980988709 * (((-2.290299256358468 / (-0.6506941184647115 * 4.5492979572195615)) + (-0.36096516726651284 * 2.6615281136334756)) * ((((4.5492979572195615 - -4.983346921677077) / 4.536900429769018) - X1 ) + (0.2093643963700238 + -0.45727096342888807))))))) * cos (X1 ))))) / 0.5105316075940269) * sin (((((((-3.673618613214983 * ((-0.45727096342888807 * (X1  / 4.956970544260436)) + -1.525181396731412)) * sin (-4.467635473851011)) / (-0.7616668770619581 / -0.8483776363799036)) - (4.5492979572195615 + ((((-1.525181396731412 - ((((4.0756214844543965 * cos (3.587233863676964)) + (1.457868710797797 * (-2.0014127606075682 / ((((0.798576273323965 + ((X1  - 0.7895433938363041) * 4.11747521558827)) / (-4.467635473851011 * -0.6506941184647115)) / (-4.176047227006968 / -3.3138047212765134)) * cos (X1 ))))) / 0.5105316075940269) * sin (((((((-3.479124225505479 * ((-0.45727096342888807 * (X1  / 4.756209639145679)) + -1.525181396731412)) * sin (-4.153525890131531)) / (-0.7616668770619581 / -0.8483776363799036)) - (4.5492979572195615 + ((((X1  * -1.1328252276323711) - -2.0014127606075682) * 3.587233863676964) - -1.1328252276323711))) * 1.745182583483805) + (-3.469164421572443 / 3.538345163698308))))) + (4.5492979572195615 / -4.176047227006968)) * -0.7616668770619581) - -1.1328252276323711))) * 1.745182583483805) + (2.0632207354405594 / 3.538345163698308))))) + (0.4218924882314914 / 4.344044973193228)) / ((0.2093643963700238 + (X1  / (0.05490045448860226 * (-2.0014127606075682 * (-0.6506941184647115 - -3.3138047212765134))))) / ((((0.24716388245140752 * cos ((4.344044973193228 * (3.5505287942604475 + (-4.617258724652789 + ((((0.798576273323965 / (((4.0756214844543965 * cos (((-3.355466730841413 * 2.3744725008158323) / 3.213604948971838))) + -1.718657584899578) * cos ((-4.188743390754595 - -1.525181396731412)))) - (((0.798576273323965 + ((X1  - 0.7895433938363041) * 4.11747521558827)) / -2.290299256358468) * ((((X1  * 4.956970544260436) - -1.7777678383464068) / -3.427132763227674) * cos ((-3.1104361379173664 / ((4.956970544260436 / 4.196515929288378) * sin (3.3726334945652354))))))) / 4.009793980988709) + (((0.2093643963700238 + (-3.355466730841413 * ((-1.5567715259267665 * sin ((((2.3184984900068004 * cos (-0.6506941184647115)) * 4.879940402368945) * 0.5105316075940269))) + 0.05490045448860226))) / ((((0.24716388245140752 * cos ((4.344044973193228 * (((-3.673618613214983 * sin (((0.798576273323965 / (((4.0756214844543965 * cos ((2.0632207354405594 + ((((4.0756214844543965 * cos (3.587233863676964)) + (1.457868710797797 * ((2.3744725008158323 * -3.1104361379173664) / ((3.587233863676964 / (-4.176047227006968 / (0.7895433938363041 + (2.3184984900068004 * (((-2.290299256358468 / (-0.6506941184647115 * 4.5492979572195615)) + (-0.36096516726651284 * 2.6615281136334756)) * ((((4.5492979572195615 - -4.983346921677077) / 4.536900429769018) - X1 ) + (0.2093643963700238 + -0.45727096342888807))))))) * cos (X1 ))))) / 0.5105316075940269) * sin (((((((-3.673618613214983 * 4.5492979572195615) * sin (-4.467635473851011)) / (-0.7616668770619581 / -0.8483776363799036)) - (4.5492979572195615 + ((((-1.525181396731412 - ((1.0776951740449183 * ((X1  / X1 ) * -3.3138047212765134)) * sin (((((((-3.479124225505479 * ((-0.45727096342888807 * (X1  / 4.756209639145679)) + -1.525181396731412)) * sin (-4.467635473851011)) / (-0.7616668770619581 / -0.8483776363799036)) - (4.5492979572195615 + ((((X1  * -1.1328252276323711) - -2.0014127606075682) * 3.587233863676964) - -1.1328252276323711))) * 1.745182583483805) + (-3.469164421572443 / 3.538345163698308))))) + (0.4218924882314914 / -4.176047227006968)) * 1.457868710797797) - -1.1328252276323711))) * (4.5492979572195615 + ((((X1  * -1.1328252276323711) - (0.1211051729232695 + -0.45727096342888807)) * 3.587233863676964) - -1.1328252276323711))) + (2.0632207354405594 / 3.538345163698308))))))) + (2.4096969823733074 * X1 )) * cos (3.3726334945652354))) - (2.3744725008158323 * (4.009793980988709 * cos (-2.3867332443360523)))))) * ((-4.153525890131531 + (2.4096969823733074 * X1 )) + (-3.1104361379173664 + (((((X1  * 2.4096969823733074) * -0.9028328472701723) * (-0.7616668770619581 * sin (4.956970544260436))) - -1.1328252276323711) + 4.956970544260436)))) + (-4.617258724652789 + ((((0.798576273323965 / (((4.0756214844543965 * cos (((4.814328243907463 * (X1  / ((-4.983346921677077 * 4.6841796801631315) * sin (4.879940402368945)))) / 3.213604948971838))) + -1.718657584899578) * cos ((-4.188743390754595 - -1.525181396731412)))) - ((X1  / 0.5105316075940269) * ((((((4.0756214844543965 * cos (3.587233863676964)) + (4.009793980988709 - ((1.5241706060914968 * sin (3.5505287942604475)) * sin ((1.457868710797797 / (4.0756214844543965 * sin (X1 ))))))) / 2.8222028343760295) * ((-4.407824618497417 * 2.0632207354405594) + (4.11747521558827 * sin ((4.009793980988709 - ((1.5241706060914968 * sin (3.5505287942604475)) * sin ((1.457868710797797 / (4.0756214844543965 * sin (X1 )))))))))) + ((X1  + X1 ) - 1.4809037480851828)) * cos (3.213604948971838)))) / 4.009793980988709) + (0.5105316075940269 - ((0.4218924882314914 * sin (-0.8483776363799036)) * -2.716886103275952)))))))) * cos (((4.009793980988709 * cos (-2.450524012227074)) + (((((X1  * 2.4096969823733074) * -0.9028328472701723) * (((-3.4709052385254657 * (((-0.8483776363799036 - -1.7777678383464068) / (-4.548474814387859 - -3.479124225505479)) / (-2.0014127606075682 * ((4.5492979572195615 - -4.983346921677077) / 4.536900429769018)))) + -2.3867332443360523) * sin (((4.344044973193228 - X1 ) * X1 )))) - -1.1328252276323711) + (4.756209639145679 * (4.956970544260436 + ((X1  + X1 ) - 1.4809037480851828))))))) + 1.457868710797797) - -1.5327193838955933)) - ((0.4218924882314914 * sin (-0.8483776363799036)) * -2.716886103275952)))))))) * cos (((4.009793980988709 * cos (-2.450524012227074)) + ((1.457868710797797 * (1.457868710797797 / ((-4.188743390754595 / (-4.176047227006968 / -3.3138047212765134)) * cos (X1 )))) + (1.0776951740449183 * ((4.0756214844543965 / -2.983619739198251) * -3.3138047212765134)))))) + (2.6615281136334756 * ((3.538345163698308 / (((1.0776951740449183 * ((4.0756214844543965 / 2.3744725008158323) * -3.3138047212765134)) * sin ((1.457868710797797 * (-3.1104361379173664 * cos (-0.45727096342888807))))) * sin ((((-3.673618613214983 * ((-0.45727096342888807 * (X1  / 4.756209639145679)) + -1.525181396731412)) * sin (-4.467635473851011)) / (((-3.1104361379173664 / (-1.5567715259267665 * sin (((((((X1  * 4.6841796801631315) + (X1  / (((-4.188743390754595 - ((-1.7777678383464068 - 0.4218924882314914) / (((4.756209639145679 + (2.0632207354405594 - 1.5564654410224747)) * -0.7616668770619581) + -0.9028328472701723))) + -3.3138047212765134) / 0.4218924882314914))) / -0.7616668770619581) * cos (-2.4454926069300242)) * -0.36096516726651284) * 0.5105316075940269)))) * cos (2.6615281136334756)) + (1.457868710797797 + (-2.1371394248538103 / -2.716886103275952))))))) * sin (0.06364946635727531)))) - -1.5327193838955933))) + -3.3138047212765134))"

# %%
# def easier_format(expression):
#     X1 = symbols('X1')
    
#     simplified_expression = simplify(expression)
    
#     return simplified_expression

# complex_expression = ""

# result = easier_format(complex_expression)
# print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 11
#       8     return simplified_expression
#      10 # Example usage with your provided complex expression
# ...

# %%
# a = a.replace(" ", "")
# print(a)
X1=1
print(eval(a))
# Out:
# 0.235093594415978

# %%
part_a = "((4.294824698455102*(X1/(-4.532855240156618/0.02722632543021053)))*-0.17702714792331875)*(((4.286692986806084*-2.295286580145861)+(0.7165152312258236/(-1.3124560181182643*(X1/(-3.0521192366115235/0.02722632543021053)))))+((((((((X1/(-3.268266518937233/0.02722632543021053))/-2.4828720491828316)*cos((((4.294824698455102*(X1/(-3.9797675297314217/0.02722632543021053))) ))))))))))"
# part_a = "((X2  + X2 ) + X1 )"
test = simplify(part_a, ratio=1.7)
print(eval(str(test)))
print(eval(part_a))

part_b = '-4.668758184299179*sin((5.367186569034243*X1**2 + (0.0035693158414072214*X1 - 1.9104118041317478)*(0.5005225213041911*X1**2*cos(66.88961488711258/X1) - 0.48150804818376792*X1**2 + (X1**2*(0.0033099327599498588*X1 + 7.9417577152296658) - 2.4198407312659406)*cos(0.020005310117503031*cos((0.21874996000170801*X1 + 1.2036930611292395)*sin(2.555990940914822*X1) + 2.295286580145861)) + (-X1**2*(0.004041850678229455*X1 + 9.6979005724941963) + 2.9549346195850414)*cos(0.020005310117503031*cos((0.21874996000170801*X1 + 1.2036930611292395)*sin(2.555990940914822*X1) + 2.295286580145861))) + (X1**2*(0.0081584098862798176*X1 + 19.575054648345859) - 5.9644874917282909)*cos(0.020005310117503031*cos((0.21874996000170801*X1 + 1.2036930611292395)*sin(2.555990940914822*X1) + 2.295286580145861)))/(0.5005225213041911*X1**2*cos(66.88961488711258/X1) - 0.48150804818376792*X1**2 + (1.9092825303046657*X1**2*(0.0017336002961393515*X1 + 4.1595508203609831) - 2.4198407312659406)*cos(0.020005310117503031*cos((0.21874996000170801*X1 + 1.2036930611292395)*sin(2.555990940914822*X1) + 2.295286580145861)) + (-X1**2*(0.004041850678229455*X1 + 9.6979005724941963) + 2.9549346195850414)*cos(0.020005310117503031*cos((0.21874996000170801*X1 + 1.2036930611292395)*sin(2.555990940914822*X1) + 2.295286580145861))))'
part_c = '-4.668758184299179*sin((5.367186569034243*X1**2 + (0.0035693158414072214*X1 - 1.9104118041317478)*(0.5005225213041911*X1**2*cos(66.88961488711258/X1) - 0.48150804818376792*X1**2 + (X1**2*(0.0033099327599498588*X1 + 7.9417577152296658) - 2.4198407312659406)*cos(0.020005310117503031*cos((0.21874996000170801*X1 + 1.2036930611292395)*sin(2.555990940914822*X1) + 2.295286580145861)) + (-X1**2*(0.004041850678229455*X1 + 9.6979005724941963) + 2.9549346195850414)*cos(0.020005310117503031*cos((0.21874996000170801*X1 + 1.2036930611292395)*sin(2.555990940914822*X1) + 2.295286580145861))) + (X1**2*(0.0081584098862798176*X1 + 19.575054648345859) - 5.9644874917282909)*cos(0.020005310117503031*cos((0.21874996000170801*X1 + 1.2036930611292395)*sin(2.555990940914822*X1) + 2.295286580145861)))/(0.5005225213041911*X1**2*cos(66.88961488711258/X1) - 0.48150804818376792*X1**2 + (X1**2*(0.0033099327599498588*X1 + 7.9417577152296658) - 2.4198407312659406)*cos(0.020005310117503031*cos((0.21874996000170801*X1 + 1.2036930611292395)*sin(2.555990940914822*X1) + 2.295286580145861)) + (-X1**2*(0.004041850678229455*X1 + 9.6979005724941963) + 2.9549346195850414)*cos(0.020005310117503031*cos((0.21874996000170801*X1 + 1.2036930611292395)*sin(2.555990940914822*X1) + 2.295286580145861))))'
part_d = '-4.668758184299179*sin((5.367186569034243*X1**2 + (0.0035693158414072214*X1 - 1.9104118041317478)*(0.5005225213041911*X1**2*cos(66.88961488711258/X1) - 0.48150804818376792*X1**2 + (X1**2*(0.0033099327599498588*X1 + 7.9417577152296658) - 2.4198407312659406)*cos(0.020005310117503031*cos((0.21874996000170801*X1 + 1.2036930611292395)*sin(2.555990940914822*X1) + 2.295286580145861)) + (-X1**2*(0.004041850678229455*X1 + 9.6979005724941963) + 2.9549346195850414)*cos(0.020005310117503031*cos((0.21874996000170801*X1 + 1.2036930611292395)*sin(2.555990940914822*X1) + 2.295286580145861))) + (X1**2*(0.0081584098862798176*X1 + 19.575054648345859) - 5.9644874917282909)*cos(0.020005310117503031*cos((0.21874996000170801*X1 + 1.2036930611292395)*sin(2.555990940914822*X1) + 2.295286580145861)))/(0.5005225213041911*X1**2*cos(66.88961488711258/X1) - 0.48150804818376792*X1**2 + (X1**2*(0.0033099327599498588*X1 + 7.9417577152296658) - 2.4198407312659406)*cos(0.020005310117503031*cos((0.21874996000170801*X1 + 1.2036930611292395)*sin(2.555990940914822*X1) + 2.295286580145861)) + (-X1**2*(0.004041850678229455*X1 + 9.6979005724941963) + 2.9549346195850414)*cos(0.020005310117503031*cos((0.21874996000170801*X1 + 1.2036930611292395)*sin(2.555990940914822*X1) + 2.295286580145861))))'
# Out:
# 0.234565839948338
# 0.234565839948338

# %%
simplify(a, ratio=1.7)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 simplify(a, ratio=1.7)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\simplify\simplify.py:615, in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     613 # do deep simplification
#     614 handled = Add, Mul, Pow, ExpBase
# --> 615 expr = expr.replace(
#     616     # here, checking for x.args is not enough because Basic has
#     617     # args but Basic does not always play well with replace, e.g.
#     618     # when simultaneous is True found expressions will be masked
#     619     # off with a Dummy but not all Basic objects in an expression
#     620     # can be replaced with a Dummy
#     621     lambda x: isinstance(x, Expr) and x.args and not isinstance(
# ...

# %%
tablica = []
item = ""
lewy_nawias = 0
for i in part_c:
    if i == '(':
        # print(len(tablica), lewy_nawias, item, i)
        if len(tablica)<=lewy_nawias:
            tablica.append(item)
        else:
            tablica[lewy_nawias]+=item
        item = ""
        lewy_nawias+=1
    elif i == ')':
        # print(len(tablica), lewy_nawias, item, i)
        if len(tablica)<=lewy_nawias:
            tablica.append(item)
        else:
            tablica[lewy_nawias]+=item
        x = simplify(tablica[lewy_nawias])
        print(x)
        tablica.pop()
        lewy_nawias-=1
        tablica[lewy_nawias]+="("+str(x)+")"
        print(tablica)
        item = ""
    else:
        item+=i
# Out:
# 0.0035693158414072214*X1 - 1.9104118041317478
# ['-4.668758184299179*sin', '', '5.367186569034243*X1**2 + (0.0035693158414072214*X1 - 1.9104118041317478)']
# 66.88961488711258/X1
# ['-4.668758184299179*sin', '', '5.367186569034243*X1**2 + (0.0035693158414072214*X1 - 1.9104118041317478)*', '0.5005225213041911*X1**2*cos(66.88961488711258/X1)']
# 0.0033099327599498588*X1 + 7.9417577152296658
# ['-4.668758184299179*sin', '', '5.367186569034243*X1**2 + (0.0035693158414072214*X1 - 1.9104118041317478)*', '0.5005225213041911*X1**2*cos(66.88961488711258/X1) - 0.48150804818376792*X1**2 + ', 'X1**2*(0.0033099327599498588*X1 + 7.9417577152296658)']
# X1**2*(0.0033099327599498588*X1 + 7.9417577152296658) - 2.4198407312659406
# ['-4.668758184299179*sin', '', '5.367186569034243*X1**2 + (0.0035693158414072214*X1 - 1.9104118041317478)*', '0.5005225213041911*X1**2*cos(66.88961488711258/X1) - 0.48150804818376792*X1**2 + (X1**2*(0.0033099327599498588*X1 + 7.9417577152296658) - 2.4198407312659406)']
# ...

# %%
print(simplify(tablica[0]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 print(simplify(tablica[0]))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\simplify\simplify.py:699, in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     696     expr = besselsimp(expr)
#     698 if expr.has(TrigonometricFunction, HyperbolicFunction):
# --> 699     expr = trigsimp(expr, deep=True)
#     701 if expr.has(log):
#     702     expr = shorter(expand_log(expr, deep=True), logcombine(expr))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\simplify\trigsimp.py:564, in trigsimp(expr, inverse, **opts)
#     553     return trigsimp_groebner(new, **opts)
#     555 trigsimpfunc = {
# ...

# %%
import numpy as np
from sympy import simplify, lambdify, symbols, sympify


def tinygp_eval(solution: str, X1: np.ndarray, X2: np.ndarray, simplify_flag: bool = False):
    print("TinyGP solution:", solution)
    x1_sym, x2_sym = symbols('X1'), symbols('X2')
    solution_sym = sympify(solution)
    print(solution)
    if simplify_flag:
        simplified = simplify(solution_sym, ratio=1.7)
        print("Simplified solution:", simplified)
        return lambdify((x1_sym, x2_sym), simplified)(X1, X2)
    else:
        return lambdify((x1_sym, x2_sym), solution_sym)(X1, X2)

xx1 = 1
xx2 = 1
tinygp_eval(a, xx1, xx2, True)
# Out:
# TinyGP solution: (((4.294824698455102 * (X1  / (-4.532855240156618 / 0.02722632543021053))) * -0.17702714792331875) * (((4.286692986806084 * -2.295286580145861) + (0.7165152312258236 / (-1.3124560181182643 * (X1  / (-3.0521192366115235 / 0.02722632543021053))))) + ((((((((X1  / (-3.268266518937233 / 0.02722632543021053)) / -2.4828720491828316) * cos ((((4.294824698455102 * (X1  / (-3.9797675297314217 / 0.02722632543021053))) * -0.17702714792331875) - (((4.286692986806084 * -2.295286580145861) * (-0.8030967835373284 / 1.502803522589609)) + (-4.668758184299179 * sin (((-4.706050122654122 / ((((((0.9248455404856148 * cos (-0.8030967835373284)) * cos (-0.6772803359089856)) * cos ((1.725525250580903 / (4.294824698455102 * (X1  / (-4.532855240156618 / 0.02722632543021053)))))) / ((((0.7319020184995519 * sin (((-0.8030967835373284 / (-2.295286580145861 * -3.772389423815934)) * -2.3819662274423195))) + ((((((((X1  / (1.5619127903168764 / 0.02722632543021053)) / 2.5506236457358744) * cos ((-0
# ...

# %%
hm = "((-1.1458726732874602 - (-4.135629737962326 + 1.0426344106895549)) - (((3.806597730565212 + (X1  * (1.172172546224914 * X1 ))) * (((X1  + 3.806597730565212) - X1 ) + ((-1.5403713303563427 + ((X1  * -4.4586129916427195) + 1.0426344106895549)) + -1.142957547592498))) + ((4.239788397344791 - (((2.8865614310301435 - -1.256865561147685) + (((4.793444004214939 / (4.03596366230569 + 4.798887665648513)) + ((X1  * -4.4586129916427195) + (4.574314282813738 * (-2.995440557153415 / (4.008390754675002 - (((((-4.135629737962326 / ((-1.1458726732874602 + (1.273818827513197 + (-4.494543167099416 + 2.675818033882039))) + (X1  * -1.1458726732874602))) / (-0.9907139479904261 * -0.0013421066028023176)) - -1.6599452875707401) + 4.008390754675002) * X1 )))))) + -1.142957547592498)) - (-4.005920758066771 * -1.6599452875707401))) + (((-2.3615257786242214 + (4.477381467058235 + ((4.5311591720566575 / (((1.3624767701769578 * ((((X1  / (((-1.256865561147685 - 3.806597730565212) - (((-1.6512248900955582 + (X1  * (1.172172546224914 * X1 ))) * ((-0.8714867757704834 - (4.793444004214939 / (2.675818033882039 - ((X1  * -4.4586129916427195) * (X1  + (X1  * -3.5895392417533625)))))) + ((((-4.338730497336712 / 1.273818827513197) + 2.675818033882039) / ((4.88698073860837 * ((-2.376004079997328 * -2.4410518731328077) + 2.9039429913971757)) + -0.9907139479904261)) + -1.142957547592498))) + (-4.240005588461565 / X1 ))) * -1.419877683662194)) * ((-1.256865561147685 - (3.5659309606844793 - 4.793444004214939)) - 1.9842596112124609)) + (3.0723634491525296 * ((4.793444004214939 / (4.03596366230569 + ((((-4.240005588461565 * 3.5659309606844793) * (-4.005920758066771 * (1.9842596112124609 - (((-0.0013421066028023176 / 4.239788397344791) + ((X1  * -4.4586129916427195) + 2.8865614310301435)) * ((3.8863615752910654 - 0.14243000748422752) - ((1.172172546224914 * X1 ) + 0.7358532406594058)))))) + ((X1  + 3.395253275555895) + ((-3.3465742240852983 - (-4.338730497336712 - -1.4578142553357312)) * (-4.890252728049558 + 1.0858768463694943)))) + X1 ))) + ((X1  * -4.4586129916427195) + (4.574314282813738 * -4.973259315643295))))) / -4.4586129916427195)) / (-4.064153723657137 * 1.5003153634364246)) + -4.338730497336712)) + (((((-1.8393165853546867 / -0.5160180204601019) - 0.6311919888734172) / ((4.854257927737697 - 3.649120075634423) * (((-2.2951261234552387 + (2.8865614310301435 + 3.806597730565212)) / (-2.995440557153415 - (((-4.973259315643295 + (X1  * (1.172172546224914 * X1 ))) * (1.172172546224914 + ((X1  + ((X1  * -4.4586129916427195) + 2.8865614310301435)) + 4.03596366230569))) + 1.2360782545067437))) * (((X1  * -0.19052471938382531) * 1.172172546224914) - ((2.36829002271877 * (-2.4410518731328077 + -1.1458726732874602)) * (3.8863615752910654 * X1 )))))) + 2.875870629440108) * (3.285287672706774 * X1 ))))) + X1 ) - 0.3110809067319842))))"
simplified = simplify(hm, ratio=1.7)
print("Simplified solution:", simplified)
# Out:
# Simplified solution: (275654.78186745182*X1**13 + 134363725.32980286*X1**12 + 1019327951.5795864*X1**11 - 5586304486.8092721*X1**10 + 180253675.76180976*X1**9 + 14813102312.977288*X1**8 - 6688076807.0495296*X1**7 + 23071287709.259697*X1**6 - 73619221200.761593*X1**5 + 46132732485.968591*X1**4 + 10233614481.837812*X1**3 - 14078706417.715967*X1**2 + 2668286147.193094*X1 - 6887446.4001725391)/(55114.662110549684*X1**10 + 26886982.127831797*X1**9 + 214592027.99734305*X1**8 - 1046612043.8291681*X1**7 - 420993582.36763365*X1**6 + 4137757674.0014095*X1**5 - 2955428859.4491483*X1**4 - 447243012.37559067*X1**3 + 806843928.84005709*X1**2 - 157812785.22500709*X1 + 339502.47422614968)

# %%
X1 = 4
eval(str(simplified))
# Out:
# 5.546305323996514
